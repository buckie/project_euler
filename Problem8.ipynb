# %% [markdown]
# The four adjacent digits in the 1000-digit number that have the greatest product are 9 × 9 × 8 × 9 = 5832.
#
# 73167176531330624919225119674426574742355349194934
# 96983520312774506326239578318016984801869478851843
# 85861560789112949495459501737958331952853208805511
# 12540698747158523863050715693290963295227443043557
# 66896648950445244523161731856403098711121722383113
# 62229893423380308135336276614282806444486645238749
# 30358907296290491560440772390713810515859307960866
# 70172427121883998797908792274921901699720888093776
# 65727333001053367881220235421809751254540594752243
# 52584907711670556013604839586446706324415722155397
# 53697817977846174064955149290862569321978468622482
# 83972241375657056057490261407972968652414535100474
# 82166370484403199890008895243450658541227588666881
# 16427171479924442928230863465674813919123162824586
# 17866458359124566529476545682848912883142607690042
# 24219022671055626321111109370544217506941658960408
# 07198403850962455444362981230987879927244284909188
# 84580156166097919133875499200524063689912560717606
# 05886116467109405077541002256983155200055935729725
# 71636269561882670428252483600823257530420752963450
#
# Find the thirteen adjacent digits in the 1000-digit number that have the greatest product. What is the value of this product?

# %%
digits1 = [int(i) for i in str(73167176531330624919225119674426574742355349194934)]
digits2 = [int(i) for i in str(96983520312774506326239578318016984801869478851843)]
digits3 = [int(i) for i in str(85861560789112949495459501737958331952853208805511)]
digits4 = [int(i) for i in str(12540698747158523863050715693290963295227443043557)]
digits5 = [int(i) for i in str(66896648950445244523161731856403098711121722383113)]
digits6 = [int(i) for i in str(62229893423380308135336276614282806444486645238749)]
digits7 = [int(i) for i in str(30358907296290491560440772390713810515859307960866)]
digits8 = [int(i) for i in str(70172427121883998797908792274921901699720888093776)]
digits9 = [int(i) for i in str(65727333001053367881220235421809751254540594752243)]
digits10 = [int(i) for i in str(52584907711670556013604839586446706324415722155397)]
digits11 = [int(i) for i in str(53697817977846174064955149290862569321978468622482)]
digits12 = [int(i) for i in str(83972241375657056057490261407972968652414535100474)]
digits13 = [int(i) for i in str(82166370484403199890008895243450658541227588666881)]
digits14 = [int(i) for i in str(16427171479924442928230863465674813919123162824586)]
digits15 = [int(i) for i in str(17866458359124566529476545682848912883142607690042)]
digits16 = [int(i) for i in str(242190226710556263211111093705442175069416589604080)]
digits17 = [int(i) for i in str(71984038509624554443629812309878799272442849091888)]
digits18 = [int(i) for i in str(45801561660979191338754992005240636899125607176060)]
digits19 = [int(i) for i in str(5886116467109405077541002256983155200055935729725)]
digits20 = [int(i) for i in str(71636269561882670428252483600823257530420752963450)]

digit_list = digits1+digits2+digits3+digits4+digits5+digits6+digits7+digits8+digits9+digits10+digits11+digits12+digits13+digits14+digits15+digits16+digits17+digits18+digits19+digits20

# %%
print digit_list
# Out:
# [7, 3, 1, 6, 7, 1, 7, 6, 5, 3, 1, 3, 3, 0, 6, 2, 4, 9, 1, 9, 2, 2, 5, 1, 1, 9, 6, 7, 4, 4, 2, 6, 5, 7, 4, 7, 4, 2, 3, 5, 5, 3, 4, 9, 1, 9, 4, 9, 3, 4, 9, 6, 9, 8, 3, 5, 2, 0, 3, 1, 2, 7, 7, 4, 5, 0, 6, 3, 2, 6, 2, 3, 9, 5, 7, 8, 3, 1, 8, 0, 1, 6, 9, 8, 4, 8, 0, 1, 8, 6, 9, 4, 7, 8, 8, 5, 1, 8, 4, 3, 8, 5, 8, 6, 1, 5, 6, 0, 7, 8, 9, 1, 1, 2, 9, 4, 9, 4, 9, 5, 4, 5, 9, 5, 0, 1, 7, 3, 7, 9, 5, 8, 3, 3, 1, 9, 5, 2, 8, 5, 3, 2, 0, 8, 8, 0, 5, 5, 1, 1, 1, 2, 5, 4, 0, 6, 9, 8, 7, 4, 7, 1, 5, 8, 5, 2, 3, 8, 6, 3, 0, 5, 0, 7, 1, 5, 6, 9, 3, 2, 9, 0, 9, 6, 3, 2, 9, 5, 2, 2, 7, 4, 4, 3, 0, 4, 3, 5, 5, 7, 6, 6, 8, 9, 6, 6, 4, 8, 9, 5, 0, 4, 4, 5, 2, 4, 4, 5, 2, 3, 1, 6, 1, 7, 3, 1, 8, 5, 6, 4, 0, 3, 0, 9, 8, 7, 1, 1, 1, 2, 1, 7, 2, 2, 3, 8, 3, 1, 1, 3, 6, 2, 2, 2, 9, 8, 9, 3, 4, 2, 3, 3, 8, 0, 3, 0, 8, 1, 3, 5, 3, 3, 6, 2, 7, 6, 6, 1, 4, 2, 8, 2, 8, 0, 6, 4, 4, 4, 4, 8, 6, 6, 4, 5, 2, 3, 8, 7, 4, 9, 3, 0, 3, 5, 8, 9, 0, 7, 2, 9, 6, 2, 9, 0, 4, 9, 1, 5, 6, 0, 4, 4, 0, 7, 7, 2, 3, 9, 0, 7, 1, 3, 8
# ...

# %%
def list_prod(lst):
    prod = 0
    for x in range(0, len(lst)-13, 1):
        test_prod = 1
        for y in range(x, x+13, 1):
            test_prod *= lst[y]
        
        if test_prod > prod:
            prod = test_prod
            
    print prod

# %%
list_prod(digit_list)
# Out:
# 23514624000
